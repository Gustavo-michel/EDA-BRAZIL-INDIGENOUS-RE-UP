# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %% [markdown]
# Importando o Dataframe

# %%
df = pd.read_csv(r"C:\Users\Pedro e Gustavo\Desktop\app\Exploratory data analysis\Data\Terras_Indigena_2017.csv")

# %%
df.head()
# Out:
#                              FID  id_objeto                      nome  \
# 0  BC250_2017_Terra_Indigena_A.1          1                   Pacheca
# 1  BC250_2017_Terra_Indigena_A.2          2                 Cantagalo
# 2  BC250_2017_Terra_Indigena_A.3          3  Guarani de Águas Brancas
# 3  BC250_2017_Terra_Indigena_A.4          4                  Capivari
# 4  BC250_2017_Terra_Indigena_A.5          5     Salto Grande do Jacuí
#
#                   nomeabrev geometriaaproximada  perimetrooficial  \
# 0                   Pacheca                 Não        28109800.0
# 1                 Cantagalo                 Não          885605.0
# 2  Guarani de Águas Brancas                 Não         9000000.0
# 3                  Capivari                 Não         3465950.0
# 4     Salto Grande do Jacuí                 Não         7258320.0
#
#    areaoficialha   grupoetnico datasituacaojuridica         situacaojuridica  \
# 0         185.21       Guarani            2001/1/15             Regularizada
# 1         283.68  Guarani Mbyá            2007/1/11  Homologada ou demarcada
# 2         230.00       Guarani            1996/2/13                Declarada
# 3          43.32  Guarani Mbyá             2003/1/8             Regularizada
# 4         234.96       Guarani           2002/11/20             Regularizada
#
#                      nometi  id_produtor  id_elementoprodutor  codigofunai  \
# 0                   Pacheca       250000                  2.0          NaN
# 1                 Cantagalo       250000                  3.0          NaN
# 2  Guarani de Águas Brancas       250000                  4.0          NaN
# 3                  Capivari       250000                  7.0          NaN
# 4     Salto Grande do Jacuí       250000                  1.0          NaN
#
#                                                 geom
# 0  MULTIPOLYGON (((-51.817032999999896 -31.170511...
# 1  MULTIPOLYGON (((-51.0340119999999 -30.19090999...
# 2  MULTIPOLYGON (((-51.60478499999989 -30.766948,...
# 3  MULTIPOLYGON (((-50.359660999999896 -30.359487...
# 4  MULTIPOLYGON (((-53.2281029999999 -29.07109199...

# %% [markdown]
# Removendo valores não utilizados

# %%
df = df.drop(columns=["FID","nome","geometriaaproximada","datasituacaojuridica","nometi", "id_produtor","codigofunai","id_elementoprodutor", "geom", "id_objeto", "areaoficialha", "grupoetnico"]).dropna()

# %%
dfst = df.copy()
dfst = dfst.drop(columns='perimetrooficial')

# %% [markdown]
# Agrupando e ordenando o DataFrame

# %%
df = df.groupby(by='nomeabrev')['perimetrooficial'].sum()

# %%
df = df.sort_values(axis=0,ascending=False)

# %%
plot = df.head(8)

# %% [markdown]
# Plot do perimetro oficial usando o top 8 tribos indigeneas

# %%
explodes = [0.05,0.03,0.01,0,0,0,0,0,]

sns.set()
plot.plot(kind='pie', 
    labels = None, 
    figsize=(12,10), 
    legend=True, 
    title='Comparação de areas indigenas (2017)', 
    explode=explodes, 
    ylabel='Perimetro oficial',
    shadow=True,
    autopct='%1.1f%%')
# Out:
# <AxesSubplot: title={'center': 'Comparação de areas indigenas (2017)'}, ylabel='Perimetro oficial'>

# %% [markdown]
# Plot Situação juridica

# %%
# onehotencoder = OneHotEncoder()

# X=onehotencoder.fit_transform(dfst['situacaojuridica'].values.reshape(-1,1)).toarray()
# X

# %%
# dfstonehot = pd.DataFrame(X, columns= ["situacaojuridica_"+str(int(i)) for i in range(dfst.shape[1])])
# dfst = pd.concat([dfst, dfstonehot], axis=1)

# dfst = dfst.drop(['situacaojuridica'], axis=1)

# dfst.head()

# %%
label_encoder = LabelEncoder()

dfst['situacaojuridica'] = label_encoder.fit_transform(dfst['situacaojuridica'])
dfst.head(30)
# Out:
#                         nomeabrev  situacaojuridica
# 0                         Pacheca                 2
# 1                       Cantagalo                 1
# 2        Guarani de Águas Brancas                 0
# 3                        Capivari                 2
# 4           Salto Grande do Jacuí                 2
# 5           Guarani Barra do Ouro                 2
# 6                        Varzinha                 2
# 7            Xikrin do Rio Catete                 0
# 8                       Koatinemo                 0
# 9             Arara do Rio Branco                 0
# 10  Terra Indígena Lago do Beruri                 0
# 11                      Jatuarana                 0
# 13                          Patuá                 0
# 14                           Zo'e                 0
# 15                        Kararaô                 0
# 16               Ilha do Camaleão                 0
# 17                         Moskow                 0
# 18          Parque do Tumucumaque                 0
# 19              Trincheira/Bacajá                 0
# 20                      Sai-Cinza                 0
# 21                           Anta                 0
# 22                        Apipica                 0
# 23                  Maraã Urubaxi                 0
# 24                       Parakanã                 0
# 25                Waimiri-Atroari                 0
# 26           Cajuhiri Atravessado                 0
# 27                         Cayabi                 0
# 28               Parana do Paricá                 0
# 29                 Turé/Mariquita                 0
# 30                Rio Paru D'Este                 0

# %%
#0 - Declarada
#1 - Homologada ou demarcada
#2 - Regularizada

sns.set()
dfst['situacaojuridica'].plot(kind='hist', legend=True, figsize=(8,6),title='Situacao juridica das terras indigenas')
# Out:
# <AxesSubplot: title={'center': 'Situacao juridica das terras indigenas'}, ylabel='Frequency'>
